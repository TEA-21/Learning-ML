# %% [markdown]
# ### Instructions

# %% [markdown]
# #### Goal of the Project
#
# This project is designed for you to practice and solve the activities that are based on the concepts covered in the following lesson:
#
#   PCA - Vector Projections

# %% [markdown]
# ---

# %% [markdown]
# #### Getting Started:
#
# 1. Follow the next 3 steps to create a copy of this colab file and start working on the project.
#
# 2. Create a duplicate copy of the Colab file as described below.
#
#   - Click on the **File menu**. A new drop-down list will appear.
#
#    <img src='https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/images/lesson-0/0_file_menu.png' width=500>
#
#   - Click on the **Save a copy in Drive** option. A duplicate copy will get created. It will open up in the new tab on your web browser.
#
#   <img src='https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/images/lesson-0/1_create_colab_duplicate_copy.png' width=500>
#
# 3. After creating the duplicate copy of the notebook, please rename it in the **YYYY-MM-DD_StudentName_Project117** format.
#
# 4. Now, write your code in the prescribed code cells.

# %% [markdown]
# ---

# %% [markdown]
# #### Problem Statement
#
# In this project, you are going to practice the concept of vectors.

# %% [markdown]
# ---

# %% [markdown]
# ### List of Activities
#
# **Activity 1:** Scaling of Vectors
#
# **Activity 2:**  Unit Vector
#
# **Activity 3:** Dot Product of Vectors

# %% [markdown]
# ---

# %% [markdown]
# #### Activity 1: Scaling of Vectors
#
# Given the following vector $\vec x$:
#
# $\begin{align}
# x = \begin{bmatrix} 5 \\ 2 \\ 9 \end{bmatrix}
# \end{align}$
#
# Scale the $\vec x$ with having a scalar number $k = 3.5$ directly using the NumPy array.
#
# **Steps to follow**:
#
# 1. Create a vector $\vec{x}= \begin{bmatrix} 5 \\ 2 \\ 9 \end{bmatrix}$ using the `array()` function of the `numpy` module.
#
# 2. Scale this vector by a magnitude of $3.5$ by multiplication of scalar to the vector.

# %%
# Scaling a vector

# Define vector 'x'


# Define scalar


# multiplication

# %% [markdown]
# **Q**: Write the values of the scaled vector.
#
# **A**:

# %% [markdown]
# After this activity, we  should be able to scale the original vector.

# %% [markdown]
# ---

# %% [markdown]
# #### Activity 2: Unit Vector
#
# Given the following vector $\vec x$:
#
# $\begin{align}
# x = \begin{bmatrix} 7 \\ 3 \\ 5 \end{bmatrix}
# \end{align}$
#
# Calculate the unit vector $x$ of $\vec x$ by dividing the vector $\vec x$ by its magnitude.

# %%
# Obtain unit vector of 'X'
# Create the vector 'X'

# Calculate the unit vector by using 'linalg.norm()' function.

# %% [markdown]
# **Q**: Write the values of the unit vector $x$.
#
# **A**:

# %% [markdown]
# After this, we  shall obtain the value of the unit vector $x$.

# %% [markdown]
# ---

# %% [markdown]
# #### Activity 3: Dot Product of Vectors
#
# In this activity you need to find the dot product of the following two vectors:
#
# \begin{align}
# \vec{X} = (5, 2, 9, 6, 3) &&  \vec{Y} = (7, 3, 5, 9, 11)
# \end{align}

# %%
# Finding dot product of two vectors 'x' and 'y'

# First vector

# Second vector

# Use 'np.dot()' function to calculate dot product

# %% [markdown]
# **Q**: What is the dot product of the given two vectors?
#
# **A**:

# %% [markdown]
# After this activity, we must be able to successfully obtain the dot product of the given two vectors $\vec{X}$ and $\vec{Y}$

# %% [markdown]
# ---

# %% [markdown]
# ### Submitting the Project:
#
# 1. After finishing the project, click on the **Share** button on the top right corner of the notebook. A new dialog box will appear.
#
#   <img src='https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/images/project-share-images/2_share_button.png' width=500>
#
# 2. In the dialog box, make sure that '**Anyone on the Internet with this link can view**' option is selected and then click on the **Copy link** button.
#
#    <img src='https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/images/project-share-images/3_copy_link.png' width=500>
#
# 3. The link of the duplicate copy (named as **YYYY-MM-DD_StudentName_Project117**) of the notebook will get copied
#
#    <img src='https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/images/project-share-images/4_copy_link_confirmation.png' width=500>
#
# 4. Go to your dashboard and click on the **My Projects** option.
#
#    <img src='https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/images/project-share-images/5_student_dashboard.png' width=800>
#
#   <img src='https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/images/project-share-images/6_my_projects.png' width=800>
#
# 5. Click on the **View Project** button for the project you want to submit.
#
#    <img src='https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/images/project-share-images/7_view_project.png' width=800>
#
# 6. Click on the **Submit Project Here** button.
#
#    <img src='https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/images/project-share-images/8_submit_project.png' width=800>
#
# 7. Paste the link to the project file named as **YYYY-MM-DD_StudentName_Project117** in the URL box and then click on the **Submit** button.
#
#    <img src='https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/images/project-share-images/9_enter_project_url.png' width=800>

# %% [markdown]
# ---
