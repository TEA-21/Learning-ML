# %%
import pandas as pd
# Updated, working URL
# Updated, verified working URL (hosted by rashida048)
url = "https://raw.githubusercontent.com/rashida048/TensorFlow-Tutorial/main/Housing.csv"

df = pd.read_csv(url)

# Check the data to confirm it matches your screenshot
df.head()
# Out:
#    Unnamed: 0     price  area  bedrooms  bathrooms  stories  mainroad  \
# 0           0  13300000  7420         4          2        3         1
# 1           1  12250000  8960         4          4        4         1
# 2           2  12250000  9960         3          2        2         1
# 3           3  12215000  7500         4          2        2         1
# 4           4  11410000  7420         4          1        2         1
#
#    guestroom  basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0          0         0                0                1        2         1
# 1          0         0                0                1        3         0
# 2          0         1                0                0        2         1
# 3          0         1                0                1        3         1
# 4          1         1                0                1        2         0
#
#    furnishingstatus
# 0                 0
# 1                 0
# 2                 1
# ...

# %%
# Save as a Text file (tab-separated)
df.to_csv('Housing_Data.txt', sep='\t', index=False)

# Save as an Excel file
df.to_excel('Housing_Data.xlsx', index=False)

print("Files saved successfully to the Colab runtime!")
# Out:
# Files saved successfully to the Colab runtime!

# %%
import pandas as pd
import numpy as np

# Verified raw link for the "Car Details v3" dataset
url = "https://raw.githubusercontent.com/manishkr1754/CarDekho_Used_Car_Price_Prediction/main/notebooks/data/cardekho_dataset.csv"

df = pd.read_csv(url)

# Preview to confirm all columns are present
df.head()
# Out:
#    Unnamed: 0       car_name    brand     model  vehicle_age  km_driven  \
# 0           0    Maruti Alto   Maruti      Alto            9     120000
# 1           1  Hyundai Grand  Hyundai     Grand            5      20000
# 2           2    Hyundai i20  Hyundai       i20           11      60000
# 3           3    Maruti Alto   Maruti      Alto            9      37000
# 4           4  Ford Ecosport     Ford  Ecosport            6      30000
#
#   seller_type fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0  Individual    Petrol            Manual    19.70     796      46.30      5
# 1  Individual    Petrol            Manual    18.90    1197      82.00      5
# 2  Individual    Petrol            Manual    17.00    1197      80.00      5
# 3  Individual    Petrol            Manual    20.92     998      67.10      5
# 4      Dealer    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# ...
